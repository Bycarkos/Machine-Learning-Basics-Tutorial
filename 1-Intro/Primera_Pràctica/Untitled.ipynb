# %% [markdown]
# # PROPOSTA PREGUNTES DE EXAMEN

# %% [markdown]
# 1. Respecte al funcionament i tractament dels nan
#
#     1. que fa aquest codi
#
#         ```python
#     for idx, column in enumerate(dataframe_original_copy):
#         dataframe_original_copy[column] = abs(np.random.normal(a[idx], b[idx], dataframe_original.shape[0]))
#
#     "return" dataframe_original_copy.where(dataframe_original.isnull(), dataframe_original)
#     ```
#         1.  substitueix els valor nan per un valor aleatori
#         2.  retorna una màscara amb els valors que son nan
#         3.  retorna un dataframe amb valors aleatoris en les posicions on hi ha nans en el dataframe original
#         4.  retorna error
#
#
#     2. Quin fillna s'ha fet servir per a genererar els dos plots (el de dalt és l'abans i el d'abaix és el després)
# <img src="fillna_plot.png" width="300">
#
#         a) S'ha fet un fillna per la mitjana
#         b) S'ha fet un fillna pel màxim
#         c) S'han eliminat els nan
#         d) cap de les altres opcions
#
#     3. Imagina que estem treballant sobre la columna de new deaths smoothed i remplacem els nan per valors respecte la distribució com a la darrera opció dels TODO. Es correcte que el np.random.normal generi nombres negatius en aquesta columna?
#
#         a). Vertader
#         b). False
#
#     4. Quan pot ser una bona pràctica eliminar una columna amb Nans.
#
#         a). Sempre és una bona pràctica
#         b). Quant tens del 60% dels valors amb nan
#         c). Quan els valors que no són nan no estan correlacionats amb cap altra variable
#         d). cap de les altres opcions

# %% [markdown]
# 2. Repecte al pandas profiler:
#
#     1. Quin de les informacions següents **NO** te les done el pandas profler:
#
#         a). Correlacio entre característiques
#         b). Estadístics bàsics de cada característica
#         c). Per cada característica si és rellevant o no per a la tasca
#         d). La memòria que ocupa cada característica
#
#     2. El Pandas profiler et dona un plot amb la interacció de totes les variables:
#         a). Vertader
#         b). Fals
#
#     3. Quines de les 4 coses pots fer amb pandas:
#
#         Pots fer plots
#         pots fer rankings de dades
#         pots fer data cleaning
#         pots treure estadístics
#         pots filtrar per indexos
#         pots convertir dataframe en numpy
#         pots fer selecció de característiques pel tipus de dades d'aquestes
#         **totes son certes**
#
#     Es pot multiplicar en 4 XD
#     4. Quina de les següents eines utilitzaries si vols X (comparar distribucions (joinplot))
#
#         a. relplot
#         b. hitmap
#         c. joinplot
#         d. pairplot
#
#     5. En el joinplot següent s'observa algun outlier?
#         1. No
#         2. Sí però no sabem per qué
#         3. Sí degut a l'alçada
#         4. Sí degut al pes

# %% [markdown]
# 3. Sobre Boxplots (imatge Boxplot)
#
#     1. La caixa central quina quantitat de samplers del data represente:
#         a. 50%
#         b. 25%
#         c. 75%
#         d. 90%
#
#     2. La linia central de la caixa és:
#         a. la mediana
#         b. la mitjana
#         c. el percentil 50%
#         d. cap de les altres opcions
#
#     3. Les dues linies que apareixen en els extrems són:
#         a. El màxim i el mínim
#         b. El màxim i el mínim estimat basat en els percentils
#         c. El màxim i el mínim estimat basat en la desviació estandard
#         d. El màxim i el mínim estimat basat en la mediana
#
#     4. Dels boxplots següents quines afirmacions són certes.
#         a. Via magna i Lleida tenen un sampling semblant però un és més esbiaxita al primer quartil que l'altra.
#         b. Viajes és la característica amb menos variabilitat
#         c. Les dues característiques amb una possible correlació més alta són central i lleida
#         d. Tarragona és la variable amb més variabilitat
#         e. Tarragona no segueix una distribució normal.
#         f. La intersecció de les caixes dels boxplots indica que les característiques estan molt mesclades.
#
#
#
#         **d. Totes les altres opcions**
