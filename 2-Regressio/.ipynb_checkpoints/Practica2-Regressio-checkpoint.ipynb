# %% [markdown]
# # Pràctica 2: La regressió
#
# ## Objectius
#
# Els objectius d'aquesta pràctica són:
# * Aplicar models de regressió, ficant l'èmfasi en:
#  * Analitzar els atributs per seleccionar els més representatius i normalitzar-los.
#  * Avaluar correctament l'error del model
#  * Visualitzar les dades i el model resultant
#  * Saber aplicar el procès de descens del gradient
#
# * Ésser capaç d'aplicar tècniques de regressió en casos reals
#
# * Validar els resultats en dades reals
#
# * Fomentar la capacitat per presentar resultats tècnics d'aprenentatge computacional de forma adequada davant altres persones

# %% [markdown]
# ## Avaluació i entregues
#
# ### Entregues
# Les pràctiques es realitzarán els divendres de 15:00 a 17:00. Cada setmana presentarem nous mètodes i algorismes vistos a la classe de teoria.
#
# L'entrega, es realitzarà el següent dijous abans de les 23:59, és a dir, tindreu les hores de classe més tota una setmana per a realitzar les tasques. Es pujará un .ipynb ja executat, on no només hi hagi codi sinó també text explicatiu de gràfiques, resultats, i analisis. Tingueu en compte que no es valora tant la quantitat, sino la qualitat del que s'hi explica. Hem d'aprendre a extreure el gra de la palla i presentar-ho de forma correcta i concisa.
#
#
# ### Avaluació
# Generalment, per tal de que veigueu varietat de dades i problematiques, es treballarà sobre dues bases de dades cada setmana. La primera serà comuna per tothom i, en aquest cas, tindrá la temática del COVID. La segona, tot i ser de lliure elecció (us deixem que l'escolliu vosaltres mateixos), haurà de tenir uns mínims de dificultat (o almenys, que tinguin una mica de gràcia).
#
#
# #### COVID data
#
# Durant el primer mes, treballarem amb una base de dades comuna, amb la temática del COVID-19. Podeu trobar la darrera actualització a [OWID DATA](https://github.com/owid/covid-19-data/tree/master/public/data), tot i que no farem servir cap dada a partir del 1 de Octubre de 2020, per això us recomanem de fer servir la que tenim penjada al Campus Virtual.
#
# #### Dataset lliure elecció
# Podeu trobar datasets de dades a qualsevol d'aquestes dues webs:
# * https://www.kaggle.com/datasets?search=machine+learning
# * https://archive.ics.uci.edu/ml/datasets.php
#
# L'objectiu será escollir un dataset adequat per la tasca que volem realitzar. LLavors, el primer apartat serà conèixer la base de dades que es té entre mans. S'han d'analitzar els diferents atributs que la composen, entendre'ls i, si no està estipulat, **caldrà fixar quin es l'atribut objectiu a predir de tots els que hi ha a la base de dades**, justificant el per què de la decisió (és útil i representatiu pel problema, per exemple, donat un conjunt de dades sobre persones: edat, gènere, pes, alçada, risc de patir càncer, aquesta última pot ser justificada com la de més interés). També podeu mirar que l'atribut objectiu tingui valors que canvien. Per exemple, no té sentit predir un atribut on el 99% dels valors són 0, i hi ha algun 1.

# %% [markdown]
# ### Pràctica 2: Regressió Lineal i Polinomial
# En aquesta pràctica es presenten diversos problemes per comprendre els mètodes de regressió numèrica. Cada apartat pot tenir una qualificació diferent.
#
# * A. Exploració de la base de dades (30%)
# * B. Ús de regressor Lineal (30%)
# * C. Demostració d'assoliment (A+B en una nova BBDD) (20%)
# * D. Implementació Regressor Lineal (20%)
# * (Extra) Implementació Regresor polinomial (+10%, max: 10pts)
#
#
#
# A continuació us posem un esquelet de codi que podeu tenir com a referència (o no)

# %%
# Codi esquelet per la pràctica de la 2 sessió: Regressió Lineal i Polinomial

import numpy as np
import pandas as pd
# %matplotlib inline
from matplotlib import pyplot as plt
import seaborn as sns
sns.set_theme()


# Visualitzarem només 3 decimals per mostra, i definim el num de files i columnes a mostrar
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.set_option('display.max_rows', 20)
pd.set_option('display.max_columns', 50)

# Funcio per a llegir dades en format csv
def load_dataset(path):
    dataset = pd.read_csv(path, header=0, delimiter=',')
    return dataset

# Carreguem dataset d'exemple
dataset = load_dataset('owid-covid-data.csv')

print("Dimensionalitat de la BBDD:", dataset.shape)
# Out:
# Dimensionalitat de la BBDD: (119911, 65)

# %% [markdown]
# A continuació veurem algunes taules i gràfiques per entendre com són les dades que tenim:

# %%
dataset
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24        5.000      5.000
# 1           AFG      Asia  Afghanistan  2020-02-25        5.000      0.000
# 2           AFG      Asia  Afghanistan  2020-02-26        5.000      0.000
# 3           AFG      Asia  Afghanistan  2020-02-27        5.000      0.000
# 4           AFG      Asia  Afghanistan  2020-02-28        5.000      0.000
# ...         ...       ...          ...         ...          ...        ...
# 119906      ZWE    Africa     Zimbabwe  2021-09-24   129134.000      0.000
# 119907      ZWE    Africa     Zimbabwe  2021-09-25   129505.000    371.000
# 119908      ZWE    Africa     Zimbabwe  2021-09-26   129625.000    120.000
# 119909      ZWE    Africa     Zimbabwe  2021-09-27   129919.000    294.000
# 119910      ZWE    Africa     Zimbabwe  2021-09-28   130272.000    353.000
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      nan           nan         nan                  nan
# 1                      nan           nan         nan                  nan
# 2                      nan           nan         nan                  nan
# 3                      nan           nan         nan                  nan
# 4                      nan           nan         nan                  nan
# ...                    ...           ...         ...                  ...
# 119906             214.571      4600.000       0.000                5.429
# 119907             252.286      4603.000       3.000                5.714
# 119908             241.000      4604.000       1.000                5.286
# 119909             247.571      4607.000       3.000                5.429
# 119910             298.000      4615.000       8.000                6.571
#
#         total_cases_per_million  new_cases_per_million  \
# 0                         0.126                  0.126
# 1                         0.126                  0.000
# 2                         0.126                  0.000
# 3                         0.126                  0.000
# 4                         0.126                  0.000
# ...                         ...                    ...
# 119906                 8556.357                  0.000
# 119907                 8580.939                 24.582
# 119908                 8588.890                  7.951
# 119909                 8608.371                 19.480
# 119910                 8631.760                 23.390
#
#         new_cases_smoothed_per_million  total_deaths_per_million  \
# 0                                  nan                       nan
# 1                                  nan                       nan
# 2                                  nan                       nan
# 3                                  nan                       nan
# 4                                  nan                       nan
# ...                                ...                       ...
# 119906                          14.217                   304.794
# 119907                          16.716                   304.993
# 119908                          15.969                   305.059
# 119909                          16.404                   305.258
# 119910                          19.745                   305.788
#
#         new_deaths_per_million  new_deaths_smoothed_per_million  \
# 0                          nan                              nan
# 1                          nan                              nan
# 2                          nan                              nan
# 3                          nan                              nan
# 4                          nan                              nan
# ...                        ...                              ...
# 119906                   0.000                            0.360
# 119907                   0.199                            0.379
# 119908                   0.066                            0.350
# 119909                   0.199                            0.360
# 119910                   0.530                            0.435
#
#         reproduction_rate  icu_patients  icu_patients_per_million  \
# 0                     nan           nan                       nan
# 1                     nan           nan                       nan
# 2                     nan           nan                       nan
# 3                     nan           nan                       nan
# 4                     nan           nan                       nan
# ...                   ...           ...                       ...
# 119906              1.140           nan                       nan
# 119907              1.140           nan                       nan
# 119908              1.140           nan                       nan
# 119909                nan           nan                       nan
# 119910                nan           nan                       nan
#
#         hosp_patients  hosp_patients_per_million  weekly_icu_admissions  \
# 0                 nan                        nan                    nan
# 1                 nan                        nan                    nan
# 2                 nan                        nan                    nan
# 3                 nan                        nan                    nan
# 4                 nan                        nan                    nan
# ...               ...                        ...                    ...
# 119906            nan                        nan                    nan
# 119907            nan                        nan                    nan
# 119908            nan                        nan                    nan
# 119909            nan                        nan                    nan
# 119910            nan                        nan                    nan
#
#         weekly_icu_admissions_per_million  weekly_hosp_admissions  \
# 0                                     nan                     nan
# 1                                     nan                     nan
# 2                                     nan                     nan
# 3                                     nan                     nan
# 4                                     nan                     nan
# ...                                   ...                     ...
# 119906                                nan                     nan
# 119907                                nan                     nan
# 119908                                nan                     nan
# 119909                                nan                     nan
# 119910                                nan                     nan
#
#         weekly_hosp_admissions_per_million  ...  \
# 0                                      nan  ...
# 1                                      nan  ...
# 2                                      nan  ...
# 3                                      nan  ...
# 4                                      nan  ...
# ...                                    ...  ...
# 119906                                 nan  ...
# 119907                                 nan  ...
# 119908                                 nan  ...
# 119909                                 nan  ...
# 119910                                 nan  ...
#
#         total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                                  nan                            nan
# 1                                  nan                            nan
# 2                                  nan                            nan
# 3                                  nan                            nan
# 4                                  nan                            nan
# ...                                ...                            ...
# 119906                          34.440                         20.020
# 119907                          34.580                         20.080
# 119908                          34.690                         20.120
# 119909                          34.880                         20.220
# 119910                          35.050                         20.280
#
#         people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# 0                                       nan                         nan
# 1                                       nan                         nan
# 2                                       nan                         nan
# 3                                       nan                         nan
# 4                                       nan                         nan
# ...                                     ...                         ...
# 119906                               14.420                         nan
# 119907                               14.500                         nan
# 119908                               14.570                         nan
# 119909                               14.660                         nan
# 119910                               14.780                         nan
#
#         new_vaccinations_smoothed_per_million  stringency_index   population  \
# 0                                         nan             8.330 39835428.000
# 1                                         nan             8.330 39835428.000
# 2                                         nan             8.330 39835428.000
# 3                                         nan             8.330 39835428.000
# 4                                         nan             8.330 39835428.000
# ...                                       ...               ...          ...
# 119906                               2073.000               nan 15092171.000
# 119907                               2141.000               nan 15092171.000
# 119908                               2081.000               nan 15092171.000
# 119909                               2073.000               nan 15092171.000
# 119910                               1953.000               nan 15092171.000
#
#         population_density median_age  aged_65_older  aged_70_older  \
# 0                   54.422     18.600          2.581          1.337
# 1                   54.422     18.600          2.581          1.337
# 2                   54.422     18.600          2.581          1.337
# 3                   54.422     18.600          2.581          1.337
# 4                   54.422     18.600          2.581          1.337
# ...                    ...        ...            ...            ...
# 119906              42.729     19.600          2.822          1.882
# 119907              42.729     19.600          2.822          1.882
# 119908              42.729     19.600          2.822          1.882
# 119909              42.729     19.600          2.822          1.882
# 119910              42.729     19.600          2.822          1.882
#
#         gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 0             1803.987              nan                597.029
# 1             1803.987              nan                597.029
# 2             1803.987              nan                597.029
# 3             1803.987              nan                597.029
# 4             1803.987              nan                597.029
# ...                ...              ...                    ...
# 119906        1899.775           21.400                307.846
# 119907        1899.775           21.400                307.846
# 119908        1899.775           21.400                307.846
# 119909        1899.775           21.400                307.846
# 119910        1899.775           21.400                307.846
#
#         diabetes_prevalence  female_smokers  male_smokers  \
# 0                     9.590             nan           nan
# 1                     9.590             nan           nan
# 2                     9.590             nan           nan
# 3                     9.590             nan           nan
# 4                     9.590             nan           nan
# ...                     ...             ...           ...
# 119906                1.820           1.600        30.700
# 119907                1.820           1.600        30.700
# 119908                1.820           1.600        30.700
# 119909                1.820           1.600        30.700
# 119910                1.820           1.600        30.700
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 0                       37.746                       0.500           64.830
# 1                       37.746                       0.500           64.830
# 2                       37.746                       0.500           64.830
# 3                       37.746                       0.500           64.830
# 4                       37.746                       0.500           64.830
# ...                        ...                         ...              ...
# 119906                  36.791                       1.700           61.490
# 119907                  36.791                       1.700           61.490
# 119908                  36.791                       1.700           61.490
# 119909                  36.791                       1.700           61.490
# 119910                  36.791                       1.700           61.490
#
#         human_development_index  excess_mortality_cumulative_absolute  \
# 0                         0.511                                   nan
# 1                         0.511                                   nan
# 2                         0.511                                   nan
# 3                         0.511                                   nan
# 4                         0.511                                   nan
# ...                         ...                                   ...
# 119906                    0.571                                   nan
# 119907                    0.571                                   nan
# 119908                    0.571                                   nan
# 119909                    0.571                                   nan
# 119910                    0.571                                   nan
#
#         excess_mortality_cumulative  excess_mortality  \
# 0                               nan               nan
# 1                               nan               nan
# 2                               nan               nan
# 3                               nan               nan
# 4                               nan               nan
# ...                             ...               ...
# 119906                          nan               nan
# 119907                          nan               nan
# 119908                          nan               nan
# 119909                          nan               nan
# 119910                          nan               nan
#
#         excess_mortality_cumulative_per_million
# 0                                           nan
# 1                                           nan
# 2                                           nan
# 3                                           nan
# 4                                           nan
# ...                                         ...
# 119906                                      nan
# 119907                                      nan
# 119908                                      nan
# 119909                                      nan
# 119910                                      nan
#
# [119911 rows x 65 columns]

# %%
dataset.describe()
# Out:
#         total_cases  new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# count    113903.000 113900.000          112885.000    103151.000  103306.000
# mean    1411010.520   6453.691            6475.774     35908.229     145.576
# std     9456979.846  39375.943           38985.751    214030.836     793.735
# min           1.000 -74347.000           -6223.000         1.000   -1918.000
# 25%        1941.000      3.000               9.143        67.000       0.000
# 50%       19989.000     91.000             113.571       593.000       2.000
# 75%      208247.000    918.000             969.571      5055.500      19.000
# max   232783704.000 906034.000          826428.571   4765112.000   17976.000
#
#        new_deaths_smoothed  total_cases_per_million  new_cases_per_million  \
# count           112885.000               113303.000             113300.000
# mean               132.612                17428.460                 82.855
# std                742.532                29833.431                193.088
# min               -232.143                    0.001              -3125.829
# 25%                  0.000                  337.047                  0.278
# 50%                  1.571                 2635.769                 10.527
# 75%                 15.571                20850.372                 80.676
# max              14723.000               216095.440               8620.690
#
#        new_cases_smoothed_per_million  total_deaths_per_million  \
# count                      112290.000                102564.000
# mean                           82.932                   365.862
# std                           163.441                   622.368
# min                          -272.971                     0.001
# 25%                             1.530                    10.104
# 50%                            14.453                    67.155
# 75%                            90.142                   440.626
# max                          3385.473                  5975.195
#
#        new_deaths_per_million  new_deaths_smoothed_per_million  \
# count              102719.000                       112290.000
# mean                    1.562                            1.416
# std                     4.124                            3.050
# min                   -75.911                          -10.844
# 25%                     0.000                            0.000
# 50%                     0.151                            0.189
# 75%                     1.367                            1.347
# max                   215.334                           94.804
#
#        reproduction_rate  icu_patients  icu_patients_per_million  \
# count          96654.000     13539.000                 13539.000
# mean               1.006       946.747                    22.333
# std                0.347      2918.471                    25.333
# min               -0.030         0.000                     0.000
# 25%                0.840        25.000                     3.367
# 50%                1.010       122.000                    12.387
# 75%                1.180       551.000                    34.465
# max                5.930     28891.000                   192.269
#
#        hosp_patients  hosp_patients_per_million  weekly_icu_admissions  \
# count      15556.000                  15556.000               1237.000
# mean        4270.229                    149.469                214.712
# std        11866.831                    197.003                499.026
# min            0.000                      0.000                  0.000
# 25%          106.000                     20.477                  5.091
# 50%          508.500                     67.891                 26.014
# 75%         2285.250                    203.218                141.262
# max       133253.000                   1544.082               4001.453
#
#        weekly_icu_admissions_per_million  weekly_hosp_admissions  \
# count                           1237.000                2178.000
# mean                              16.613                3042.328
# std                               31.385               10412.309
# min                                0.000                   0.000
# 25%                                1.431                  39.005
# 50%                                5.640                 243.343
# 75%                               18.018                1217.773
# max                              279.224              116307.000
#
#        weekly_hosp_admissions_per_million   new_tests   total_tests  \
# count                            2178.000   51679.000     51613.000
# mean                               89.130   54458.179  10496214.964
# std                               186.954  191559.845  44263614.425
# min                                 0.000       1.000         0.000
# 25%                                 8.273    2029.000    228335.000
# 50%                                32.225    7330.000   1145366.000
# 75%                               101.390   28084.500   4697021.000
# max                              2656.911 3740296.000 570080992.000
#
#        total_tests_per_thousand  new_tests_per_thousand  ...  \
# count                 51613.000               51679.000  ...
# mean                    440.190                   2.418  ...
# std                    1073.431                   6.509  ...
# min                       0.000                   0.000  ...
# 25%                      19.508                   0.177  ...
# 50%                      98.603                   0.717  ...
# 75%                     403.339                   2.204  ...
# max                   14781.267                 325.760  ...
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                       27079.000                      25929.000
# mean                           43.059                         25.867
# std                            44.846                         24.232
# min                             0.000                          0.000
# 25%                             4.980                          3.760
# 50%                            25.690                         17.900
# 75%                            72.040                         44.660
# max                           236.050                        118.540
#
#        people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# count                            22878.000                    2867.000
# mean                                19.410                       1.515
# std                                 21.353                       4.646
# min                                  0.000                       0.000
# 25%                                  2.220                       0.000
# 50%                                 10.340                       0.010
# 75%                                 31.697                       0.290
# max                                117.510                      37.050
#
#        new_vaccinations_smoothed_per_million  stringency_index     population  \
# count                              48402.000        100191.000     119097.000
# mean                                3487.525            57.035  122667968.219
# std                                 4358.805            20.718  677210974.588
# min                                    0.000             0.000         47.000
# 25%                                  501.000            42.825    2078723.000
# 50%                                 2179.000            58.330    9634162.000
# 75%                                 5143.750            72.690   33933611.000
# max                               117497.000           100.000 7874965732.000
#
#        population_density  median_age  aged_65_older  aged_70_older  \
# count          110870.000  105900.000     104722.000     105319.000
# mean              395.505      30.522          8.762          5.545
# std              1842.468       9.124          6.192          4.223
# min                 0.137      15.100          1.144          0.526
# 25%                36.253      22.200          3.466          2.063
# 50%                83.479      29.700          6.378          3.871
# 75%               209.588      39.100         14.178          8.678
# max             20546.766      48.200         27.049         18.493
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# count      106515.000        71480.000             106185.000
# mean        19249.208           13.480                259.244
# std         20051.037           19.983                119.318
# min           661.240            0.100                 79.370
# 25%          4449.898            0.600                168.711
# 50%         12895.635            2.200                243.811
# 75%         27216.445           21.200                329.942
# max        116935.600           77.600                724.417
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# count           109475.000       82910.000     81706.000
# mean                 8.013          10.593        32.737
# std                  4.275          10.505        13.504
# min                  0.990           0.100         7.700
# 25%                  5.310           1.900        21.600
# 50%                  7.110           6.300        31.400
# 75%                 10.080          19.300        41.100
# max                 30.530          44.000        78.100
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# count               53351.000                   96551.000       113754.000
# mean                   50.744                       3.024           73.258
# std                    31.753                       2.453            7.541
# min                     1.188                       0.100           53.280
# 25%                    19.351                       1.300           67.920
# 50%                    49.839                       2.400           74.620
# 75%                    82.502                       3.861           78.740
# max                   100.000                      13.800           86.750
#
#        human_development_index  excess_mortality_cumulative_absolute  \
# count               106278.000                              4129.000
# mean                     0.727                             28797.992
# std                      0.150                             83446.267
# min                      0.394                            -31959.400
# 25%                      0.602                              -292.600
# 50%                      0.744                              1279.200
# 75%                      0.848                             17379.800
# max                      0.957                            675683.400
#
#        excess_mortality_cumulative  excess_mortality  \
# count                     4129.000          4275.000
# mean                         8.190            15.037
# std                         16.123            31.190
# min                        -27.350           -95.920
# 25%                         -1.600            -1.555
# 50%                          4.520             5.640
# 75%                         13.170            21.185
# max                        106.850           372.820
#
#        excess_mortality_cumulative_per_million
# count                                 4129.000
# mean                                   701.843
# std                                   1097.895
# min                                  -1728.844
# 25%                                    -65.793
# 50%                                    271.653
# 75%                                   1194.686
# max                                   6084.213
#
# [8 rows x 60 columns]

# %%
covid_spain = dataset[dataset.location=="Spain"]
covid_italy = dataset[dataset.location=="Italy"]
covid_spain
# Out:
#        iso_code continent location        date  total_cases  new_cases  \
# 101423      ESP    Europe    Spain  2020-02-01        1.000      1.000
# 101424      ESP    Europe    Spain  2020-02-02        1.000      0.000
# 101425      ESP    Europe    Spain  2020-02-03        1.000      0.000
# 101426      ESP    Europe    Spain  2020-02-04        1.000      0.000
# 101427      ESP    Europe    Spain  2020-02-05        1.000      0.000
# ...         ...       ...      ...         ...          ...        ...
# 102024      ESP    Europe    Spain  2021-09-24  4946601.000   2746.000
# 102025      ESP    Europe    Spain  2021-09-25  4946601.000      0.000
# 102026      ESP    Europe    Spain  2021-09-26  4946601.000      0.000
# 102027      ESP    Europe    Spain  2021-09-27  4951640.000   5039.000
# 102028      ESP    Europe    Spain  2021-09-28  4953930.000   2290.000
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 101423                 nan           nan         nan                  nan
# 101424                 nan           nan         nan                  nan
# 101425                 nan           nan         nan                  nan
# 101426                 nan           nan         nan                  nan
# 101427                 nan           nan         nan                  nan
# ...                    ...           ...         ...                  ...
# 102024            2436.429     86229.000      44.000               63.714
# 102025            2436.429     86229.000       0.000               63.714
# 102026            2436.429     86229.000       0.000               63.714
# 102027            2300.857     86298.000      69.000               56.714
# 102028            2278.000     86358.000      60.000               53.571
#
#         total_cases_per_million  new_cases_per_million  \
# 101423                    0.021                  0.021
# 101424                    0.021                  0.000
# 101425                    0.021                  0.000
# 101426                    0.021                  0.000
# 101427                    0.021                  0.000
# ...                         ...                    ...
# 102024               105820.487                 58.744
# 102025               105820.487                  0.000
# 102026               105820.487                  0.000
# 102027               105928.284                107.797
# 102028               105977.273                 48.989
#
#         new_cases_smoothed_per_million  total_deaths_per_million  \
# 101423                             nan                       nan
# 101424                             nan                       nan
# 101425                             nan                       nan
# 101426                             nan                       nan
# 101427                             nan                       nan
# ...                                ...                       ...
# 102024                          52.121                  1844.660
# 102025                          52.121                  1844.660
# 102026                          52.121                  1844.660
# 102027                          49.221                  1846.136
# 102028                          48.732                  1847.419
#
#         new_deaths_per_million  new_deaths_smoothed_per_million  \
# 101423                     nan                              nan
# 101424                     nan                              nan
# 101425                     nan                              nan
# 101426                     nan                              nan
# 101427                     nan                              nan
# ...                        ...                              ...
# 102024                   0.941                            1.363
# 102025                   0.000                            1.363
# 102026                   0.000                            1.363
# 102027                   1.476                            1.213
# 102028                   1.284                            1.146
#
#         reproduction_rate  icu_patients  icu_patients_per_million  \
# 101423                nan           nan                       nan
# 101424                nan           nan                       nan
# 101425                nan           nan                       nan
# 101426                nan           nan                       nan
# 101427                nan           nan                       nan
# ...                   ...           ...                       ...
# 102024              0.740           nan                       nan
# 102025              0.740           nan                       nan
# 102026              0.740           nan                       nan
# 102027                nan           nan                       nan
# 102028                nan           nan                       nan
#
#         hosp_patients  hosp_patients_per_million  weekly_icu_admissions  \
# 101423            nan                        nan                    nan
# 101424            nan                        nan                  2.963
# 101425            nan                        nan                    nan
# 101426            nan                        nan                    nan
# 101427            nan                        nan                    nan
# ...               ...                        ...                    ...
# 102024            nan                        nan                    nan
# 102025            nan                        nan                    nan
# 102026            nan                        nan                    nan
# 102027            nan                        nan                    nan
# 102028            nan                        nan                    nan
#
#         weekly_icu_admissions_per_million  weekly_hosp_admissions  \
# 101423                                nan                     nan
# 101424                              0.063                  17.777
# 101425                                nan                     nan
# 101426                                nan                     nan
# 101427                                nan                     nan
# ...                                   ...                     ...
# 102024                                nan                     nan
# 102025                                nan                     nan
# 102026                                nan                     nan
# 102027                                nan                     nan
# 102028                                nan                     nan
#
#         weekly_hosp_admissions_per_million  ...  \
# 101423                                 nan  ...
# 101424                               0.380  ...
# 101425                                 nan  ...
# 101426                                 nan  ...
# 101427                                 nan  ...
# ...                                    ...  ...
# 102024                                 nan  ...
# 102025                                 nan  ...
# 102026                                 nan  ...
# 102027                                 nan  ...
# 102028                                 nan  ...
#
#         total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 101423                             nan                            nan
# 101424                             nan                            nan
# 101425                             nan                            nan
# 101426                             nan                            nan
# 101427                             nan                            nan
# ...                                ...                            ...
# 102024                             nan                            nan
# 102025                             nan                            nan
# 102026                         149.460                         80.460
# 102027                         149.610                         80.500
# 102028                             nan                            nan
#
#         people_fully_vaccinated_per_hundred  total_boosters_per_hundred  \
# 101423                                  nan                         nan
# 101424                                  nan                         nan
# 101425                                  nan                         nan
# 101426                                  nan                         nan
# 101427                                  nan                         nan
# ...                                     ...                         ...
# 102024                                  nan                         nan
# 102025                                  nan                         nan
# 102026                               77.970                         nan
# 102027                               78.090                         nan
# 102028                                  nan                         nan
#
#         new_vaccinations_smoothed_per_million  stringency_index   population  \
# 101423                                    nan            11.110 46745211.000
# 101424                                    nan            11.110 46745211.000
# 101425                                    nan            11.110 46745211.000
# 101426                                    nan            11.110 46745211.000
# 101427                                    nan            11.110 46745211.000
# ...                                       ...               ...          ...
# 102024                               1765.000            42.130 46745211.000
# 102025                               1556.000            42.130 46745211.000
# 102026                               1346.000            42.130 46745211.000
# 102027                               1558.000               nan 46745211.000
# 102028                                    nan               nan 46745211.000
#
#         population_density median_age  aged_65_older  aged_70_older  \
# 101423              93.105     45.500         19.436         13.799
# 101424              93.105     45.500         19.436         13.799
# 101425              93.105     45.500         19.436         13.799
# 101426              93.105     45.500         19.436         13.799
# 101427              93.105     45.500         19.436         13.799
# ...                    ...        ...            ...            ...
# 102024              93.105     45.500         19.436         13.799
# 102025              93.105     45.500         19.436         13.799
# 102026              93.105     45.500         19.436         13.799
# 102027              93.105     45.500         19.436         13.799
# 102028              93.105     45.500         19.436         13.799
#
#         gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 101423       34272.360            1.000                 99.403
# 101424       34272.360            1.000                 99.403
# 101425       34272.360            1.000                 99.403
# 101426       34272.360            1.000                 99.403
# 101427       34272.360            1.000                 99.403
# ...                ...              ...                    ...
# 102024       34272.360            1.000                 99.403
# 102025       34272.360            1.000                 99.403
# 102026       34272.360            1.000                 99.403
# 102027       34272.360            1.000                 99.403
# 102028       34272.360            1.000                 99.403
#
#         diabetes_prevalence  female_smokers  male_smokers  \
# 101423                7.170          27.400        31.400
# 101424                7.170          27.400        31.400
# 101425                7.170          27.400        31.400
# 101426                7.170          27.400        31.400
# 101427                7.170          27.400        31.400
# ...                     ...             ...           ...
# 102024                7.170          27.400        31.400
# 102025                7.170          27.400        31.400
# 102026                7.170          27.400        31.400
# 102027                7.170          27.400        31.400
# 102028                7.170          27.400        31.400
#
#         handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 101423                     nan                       2.970           83.560
# 101424                     nan                       2.970           83.560
# 101425                     nan                       2.970           83.560
# 101426                     nan                       2.970           83.560
# 101427                     nan                       2.970           83.560
# ...                        ...                         ...              ...
# 102024                     nan                       2.970           83.560
# 102025                     nan                       2.970           83.560
# 102026                     nan                       2.970           83.560
# 102027                     nan                       2.970           83.560
# 102028                     nan                       2.970           83.560
#
#         human_development_index  excess_mortality_cumulative_absolute  \
# 101423                    0.904                                   nan
# 101424                    0.904                             -3085.800
# 101425                    0.904                                   nan
# 101426                    0.904                                   nan
# 101427                    0.904                                   nan
# ...                         ...                                   ...
# 102024                    0.904                                   nan
# 102025                    0.904                                   nan
# 102026                    0.904                                   nan
# 102027                    0.904                                   nan
# 102028                    0.904                                   nan
#
#         excess_mortality_cumulative  excess_mortality  \
# 101423                          nan               nan
# 101424                       -6.050            -0.900
# 101425                          nan               nan
# 101426                          nan               nan
# 101427                          nan               nan
# ...                             ...               ...
# 102024                          nan               nan
# 102025                          nan               nan
# 102026                          nan               nan
# 102027                          nan               nan
# 102028                          nan               nan
#
#         excess_mortality_cumulative_per_million
# 101423                                      nan
# 101424                                  -66.013
# 101425                                      nan
# 101426                                      nan
# 101427                                      nan
# ...                                         ...
# 102024                                      nan
# 102025                                      nan
# 102026                                      nan
# 102027                                      nan
# 102028                                      nan
#
# [606 rows x 65 columns]

# %%
dataset["datetime"] = pd.to_datetime(dataset["date"], format='%Y-%m-%d', errors='ignore')
dataset
# Out:
#        iso_code continent     location        date  total_cases  new_cases  \
# 0           AFG      Asia  Afghanistan  2020-02-24        5.000      5.000
# 1           AFG      Asia  Afghanistan  2020-02-25        5.000      0.000
# 2           AFG      Asia  Afghanistan  2020-02-26        5.000      0.000
# 3           AFG      Asia  Afghanistan  2020-02-27        5.000      0.000
# 4           AFG      Asia  Afghanistan  2020-02-28        5.000      0.000
# ...         ...       ...          ...         ...          ...        ...
# 119906      ZWE    Africa     Zimbabwe  2021-09-24   129134.000      0.000
# 119907      ZWE    Africa     Zimbabwe  2021-09-25   129505.000    371.000
# 119908      ZWE    Africa     Zimbabwe  2021-09-26   129625.000    120.000
# 119909      ZWE    Africa     Zimbabwe  2021-09-27   129919.000    294.000
# 119910      ZWE    Africa     Zimbabwe  2021-09-28   130272.000    353.000
#
#         new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  \
# 0                      nan           nan         nan                  nan
# 1                      nan           nan         nan                  nan
# 2                      nan           nan         nan                  nan
# 3                      nan           nan         nan                  nan
# 4                      nan           nan         nan                  nan
# ...                    ...           ...         ...                  ...
# 119906             214.571      4600.000       0.000                5.429
# 119907             252.286      4603.000       3.000                5.714
# 119908             241.000      4604.000       1.000                5.286
# 119909             247.571      4607.000       3.000                5.429
# 119910             298.000      4615.000       8.000                6.571
#
#         total_cases_per_million  new_cases_per_million  \
# 0                         0.126                  0.126
# 1                         0.126                  0.000
# 2                         0.126                  0.000
# 3                         0.126                  0.000
# 4                         0.126                  0.000
# ...                         ...                    ...
# 119906                 8556.357                  0.000
# 119907                 8580.939                 24.582
# 119908                 8588.890                  7.951
# 119909                 8608.371                 19.480
# 119910                 8631.760                 23.390
#
#         new_cases_smoothed_per_million  total_deaths_per_million  \
# 0                                  nan                       nan
# 1                                  nan                       nan
# 2                                  nan                       nan
# 3                                  nan                       nan
# 4                                  nan                       nan
# ...                                ...                       ...
# 119906                          14.217                   304.794
# 119907                          16.716                   304.993
# 119908                          15.969                   305.059
# 119909                          16.404                   305.258
# 119910                          19.745                   305.788
#
#         new_deaths_per_million  new_deaths_smoothed_per_million  \
# 0                          nan                              nan
# 1                          nan                              nan
# 2                          nan                              nan
# 3                          nan                              nan
# 4                          nan                              nan
# ...                        ...                              ...
# 119906                   0.000                            0.360
# 119907                   0.199                            0.379
# 119908                   0.066                            0.350
# 119909                   0.199                            0.360
# 119910                   0.530                            0.435
#
#         reproduction_rate  icu_patients  icu_patients_per_million  \
# 0                     nan           nan                       nan
# 1                     nan           nan                       nan
# 2                     nan           nan                       nan
# 3                     nan           nan                       nan
# 4                     nan           nan                       nan
# ...                   ...           ...                       ...
# 119906              1.140           nan                       nan
# 119907              1.140           nan                       nan
# 119908              1.140           nan                       nan
# 119909                nan           nan                       nan
# 119910                nan           nan                       nan
#
#         hosp_patients  hosp_patients_per_million  weekly_icu_admissions  \
# 0                 nan                        nan                    nan
# 1                 nan                        nan                    nan
# 2                 nan                        nan                    nan
# 3                 nan                        nan                    nan
# 4                 nan                        nan                    nan
# ...               ...                        ...                    ...
# 119906            nan                        nan                    nan
# 119907            nan                        nan                    nan
# 119908            nan                        nan                    nan
# 119909            nan                        nan                    nan
# 119910            nan                        nan                    nan
#
#         weekly_icu_admissions_per_million  weekly_hosp_admissions  \
# 0                                     nan                     nan
# 1                                     nan                     nan
# 2                                     nan                     nan
# 3                                     nan                     nan
# 4                                     nan                     nan
# ...                                   ...                     ...
# 119906                                nan                     nan
# 119907                                nan                     nan
# 119908                                nan                     nan
# 119909                                nan                     nan
# 119910                                nan                     nan
#
#         weekly_hosp_admissions_per_million  ...  \
# 0                                      nan  ...
# 1                                      nan  ...
# 2                                      nan  ...
# 3                                      nan  ...
# 4                                      nan  ...
# ...                                    ...  ...
# 119906                                 nan  ...
# 119907                                 nan  ...
# 119908                                 nan  ...
# 119909                                 nan  ...
# 119910                                 nan  ...
#
#         people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                                 nan                                  nan
# 1                                 nan                                  nan
# 2                                 nan                                  nan
# 3                                 nan                                  nan
# 4                                 nan                                  nan
# ...                               ...                                  ...
# 119906                         20.020                               14.420
# 119907                         20.080                               14.500
# 119908                         20.120                               14.570
# 119909                         20.220                               14.660
# 119910                         20.280                               14.780
#
#         total_boosters_per_hundred  new_vaccinations_smoothed_per_million  \
# 0                              nan                                    nan
# 1                              nan                                    nan
# 2                              nan                                    nan
# 3                              nan                                    nan
# 4                              nan                                    nan
# ...                            ...                                    ...
# 119906                         nan                               2073.000
# 119907                         nan                               2141.000
# 119908                         nan                               2081.000
# 119909                         nan                               2073.000
# 119910                         nan                               1953.000
#
#         stringency_index   population  population_density  median_age  \
# 0                  8.330 39835428.000              54.422      18.600
# 1                  8.330 39835428.000              54.422      18.600
# 2                  8.330 39835428.000              54.422      18.600
# 3                  8.330 39835428.000              54.422      18.600
# 4                  8.330 39835428.000              54.422      18.600
# ...                  ...          ...                 ...         ...
# 119906               nan 15092171.000              42.729      19.600
# 119907               nan 15092171.000              42.729      19.600
# 119908               nan 15092171.000              42.729      19.600
# 119909               nan 15092171.000              42.729      19.600
# 119910               nan 15092171.000              42.729      19.600
#
#        aged_65_older  aged_70_older  gdp_per_capita  extreme_poverty  \
# 0              2.581          1.337        1803.987              nan
# 1              2.581          1.337        1803.987              nan
# 2              2.581          1.337        1803.987              nan
# 3              2.581          1.337        1803.987              nan
# 4              2.581          1.337        1803.987              nan
# ...              ...            ...             ...              ...
# 119906         2.822          1.882        1899.775           21.400
# 119907         2.822          1.882        1899.775           21.400
# 119908         2.822          1.882        1899.775           21.400
# 119909         2.822          1.882        1899.775           21.400
# 119910         2.822          1.882        1899.775           21.400
#
#         cardiovasc_death_rate  diabetes_prevalence  female_smokers  \
# 0                     597.029                9.590             nan
# 1                     597.029                9.590             nan
# 2                     597.029                9.590             nan
# 3                     597.029                9.590             nan
# 4                     597.029                9.590             nan
# ...                       ...                  ...             ...
# 119906                307.846                1.820           1.600
# 119907                307.846                1.820           1.600
# 119908                307.846                1.820           1.600
# 119909                307.846                1.820           1.600
# 119910                307.846                1.820           1.600
#
#         male_smokers  handwashing_facilities  hospital_beds_per_thousand  \
# 0                nan                  37.746                       0.500
# 1                nan                  37.746                       0.500
# 2                nan                  37.746                       0.500
# 3                nan                  37.746                       0.500
# 4                nan                  37.746                       0.500
# ...              ...                     ...                         ...
# 119906        30.700                  36.791                       1.700
# 119907        30.700                  36.791                       1.700
# 119908        30.700                  36.791                       1.700
# 119909        30.700                  36.791                       1.700
# 119910        30.700                  36.791                       1.700
#
#         life_expectancy  human_development_index  \
# 0                64.830                    0.511
# 1                64.830                    0.511
# 2                64.830                    0.511
# 3                64.830                    0.511
# 4                64.830                    0.511
# ...                 ...                      ...
# 119906           61.490                    0.571
# 119907           61.490                    0.571
# 119908           61.490                    0.571
# 119909           61.490                    0.571
# 119910           61.490                    0.571
#
#         excess_mortality_cumulative_absolute  excess_mortality_cumulative  \
# 0                                        nan                          nan
# 1                                        nan                          nan
# 2                                        nan                          nan
# 3                                        nan                          nan
# 4                                        nan                          nan
# ...                                      ...                          ...
# 119906                                   nan                          nan
# 119907                                   nan                          nan
# 119908                                   nan                          nan
# 119909                                   nan                          nan
# 119910                                   nan                          nan
#
#         excess_mortality  excess_mortality_cumulative_per_million   datetime
# 0                    nan                                      nan 2020-02-24
# 1                    nan                                      nan 2020-02-25
# 2                    nan                                      nan 2020-02-26
# 3                    nan                                      nan 2020-02-27
# 4                    nan                                      nan 2020-02-28
# ...                  ...                                      ...        ...
# 119906               nan                                      nan 2021-09-24
# 119907               nan                                      nan 2021-09-25
# 119908               nan                                      nan 2021-09-26
# 119909               nan                                      nan 2021-09-27
# 119910               nan                                      nan 2021-09-28
#
# [119911 rows x 66 columns]

# %%
fg = sns.FacetGrid(data=dataset, hue='continent',aspect=2)
fg.map(plt.scatter, 'datetime', 'new_cases_per_million').add_legend()

# %%
print("Quina correlació entre aquests atributs hi veieu?")

selected_columns = ["location", "new_cases", "new_deaths", "total_cases", "total_deaths", "stringency_index"]
sns.pairplot(covid_spain[selected_columns])
plt.show()
# Out:
# Quina correlació entre aquests atributs hi veieu?

# %%
print("Què passa si utilitzem les dades smoothed?")

selected_columns = ["location", "new_cases_smoothed", "new_deaths_smoothed", "total_cases", "total_deaths", "stringency_index"]
sns.pairplot(covid_spain[selected_columns])
plt.show()

# %%
print("I si busquem alguna correlació entre paisos per un dia concret?")

covid_agost = dataset[dataset.date=="2020-08-01"]
covid_agost
# Out:
# I si busquem alguna correlació entre paisos per un dia concret?
#        iso_code      continent       location        date  total_cases  \
# 136         ABW  North America          Aruba  2020-08-01      121.000
# 406         AFG           Asia    Afghanistan  2020-08-01    36710.000
# 594         AGO         Africa         Angola  2020-08-01     1109.000
# 777         AIA  North America       Anguilla  2020-08-01        3.000
# 978         ALB         Europe        Albania  2020-08-01     5276.000
# ...         ...            ...            ...         ...          ...
# 45086       ZAF         Africa   South Africa  2020-08-01   493183.000
# 45277       ZMB         Africa         Zambia  2020-08-01     5963.000
# 45466       ZWE         Africa       Zimbabwe  2020-08-01     3169.000
# 45736  OWID_WRL            NaN          World  2020-08-01 17577170.000
# 46006       NaN            NaN  International  2020-08-01      696.000
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# 136        1.000               0.429         3.000       0.000
# 406      168.000              96.286      1283.000      12.000
# 594       31.000              36.857        51.000       3.000
# 777        0.000               0.000         0.000       0.000
# 978       79.000             100.857       157.000       3.000
# ...          ...                 ...           ...         ...
# 45086  11014.000           10169.571      8005.000     193.000
# 45277    408.000             301.000       151.000       2.000
# 45466     77.000             124.714        67.000      14.000
# 45736 279106.000          259257.571    674450.000    6120.000
# 46006        nan                 nan         7.000         nan
#
#        new_deaths_smoothed  total_cases_per_million  new_cases_per_million  \
# 136                  0.000                 1133.320                  9.366
# 406                  5.286                  943.015                  4.316
# 594                  2.571                   33.743                  0.943
# 777                  0.000                  199.973                  0.000
# 978                  4.143                 1833.345                 27.452
# ...                    ...                      ...                    ...
# 45086              237.429                 8315.527                185.706
# 45277                3.000                  324.359                 22.193
# 45466                5.000                  213.215                  5.181
# 45736             5666.000                 2254.987                 35.807
# 46006                  nan                      nan                    nan
#
#        new_cases_smoothed_per_million  total_deaths_per_million  \
# 136                             4.014                    28.099
# 406                             2.473                    32.958
# 594                             1.121                     1.552
# 777                             0.000                     0.000
# 978                            35.047                    54.556
# ...                               ...                       ...
# 45086                         171.468                   134.972
# 45277                          16.373                     8.214
# 45466                           8.391                     4.508
# 45736                          33.260                    86.526
# 46006                             nan                       nan
#
#        new_deaths_per_million  new_deaths_smoothed_per_million  new_tests  \
# 136                     0.000                            0.000        nan
# 406                     0.308                            0.136        nan
# 594                     0.091                            0.078        nan
# 777                     0.000                            0.000        nan
# 978                     1.042                            1.440        nan
# ...                       ...                              ...        ...
# 45086                   3.254                            4.003  42450.000
# 45277                   0.109                            0.163   1908.000
# 45466                   0.942                            0.336   1445.000
# 45736                   0.785                            0.727        nan
# 46006                     nan                              nan        nan
#
#        total_tests  total_tests_per_thousand  new_tests_per_thousand  \
# 136            nan                       nan                     nan
# 406            nan                       nan                     nan
# 594            nan                       nan                     nan
# 777            nan                       nan                     nan
# 978            nan                       nan                     nan
# ...            ...                       ...                     ...
# 45086  3001985.000                    50.616                   0.716
# 45277    85001.000                     4.624                   0.104
# 45466    61577.000                     4.143                   0.097
# 45736          nan                       nan                     nan
# 46006          nan                       nan                     nan
#
#        new_tests_smoothed  new_tests_smoothed_per_thousand  tests_per_case  \
# 136                   nan                              nan             nan
# 406                   nan                              nan             nan
# 594                   nan                              nan             nan
# 777                   nan                              nan             nan
# 978                   nan                              nan             nan
# ...                   ...                              ...             ...
# 45086           38739.000                            0.653           3.809
# 45277            1276.000                            0.069           4.239
# 45466            1367.000                            0.092          10.961
# 45736                 nan                              nan             nan
# 46006                 nan                              nan             nan
#
#        positive_rate      tests_units  stringency_index     population  \
# 136              nan              NaN            32.410     106766.000
# 406              nan              NaN            78.700   38928341.000
# 594              nan              NaN            79.170   32866268.000
# 777              nan              NaN            18.520      15002.000
# 978              nan              NaN            59.260    2877800.000
# ...              ...              ...               ...            ...
# 45086          0.263    people tested            80.560   59308690.000
# 45277          0.236  tests performed            50.930   18383956.000
# 45466          0.091  tests performed            80.560   14862927.000
# 45736            nan              NaN               nan 7794798729.000
# 46006            nan              NaN               nan            nan
#
#        population_density  median_age  aged_65_older  aged_70_older  \
# 136               584.800      41.200         13.085          7.452
# 406                54.422      18.600          2.581          1.337
# 594                23.890      16.800          2.405          1.362
# 777                   nan         nan            nan            nan
# 978               104.871      38.000         13.188          8.643
# ...                   ...         ...            ...            ...
# 45086              46.754      27.300          5.344          3.053
# 45277              22.995      17.700          2.480          1.542
# 45466              42.729      19.600          2.822          1.882
# 45736              58.045      30.900          8.696          5.355
# 46006                 nan         nan            nan            nan
#
#        gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# 136         35973.781              nan                    nan
# 406          1803.987              nan                597.029
# 594          5819.495              nan                276.045
# 777               nan              nan                    nan
# 978         11803.431            1.100                304.195
# ...               ...              ...                    ...
# 45086       12294.876           18.900                200.380
# 45277        3689.251           57.500                234.499
# 45466        1899.775           21.400                307.846
# 45736       15469.207           10.000                233.070
# 46006             nan              nan                    nan
#
#        diabetes_prevalence  female_smokers  male_smokers  \
# 136                 11.620             nan           nan
# 406                  9.590             nan           nan
# 594                  3.940             nan           nan
# 777                    nan             nan           nan
# 978                 10.080           7.100        51.200
# ...                    ...             ...           ...
# 45086                5.520           8.100        33.200
# 45277                3.940           3.100        24.700
# 45466                1.820           1.600        30.700
# 45736                8.510           6.434        34.635
# 46006                  nan             nan           nan
#
#        handwashing_facilities  hospital_beds_per_thousand  life_expectancy  \
# 136                       nan                         nan           76.290
# 406                    37.746                       0.500           64.830
# 594                    26.664                         nan           61.150
# 777                       nan                         nan           81.880
# 978                       nan                       2.890           78.570
# ...                       ...                         ...              ...
# 45086                  43.993                       2.320           64.130
# 45277                  13.938                       2.000           63.890
# 45466                  36.791                       1.700           61.490
# 45736                  60.130                       2.705           72.580
# 46006                     nan                         nan              nan
#
#        human_development_index   datetime
# 136                        nan 2020-08-01
# 406                      0.498 2020-08-01
# 594                      0.581 2020-08-01
# 777                        nan 2020-08-01
# 978                      0.785 2020-08-01
# ...                        ...        ...
# 45086                    0.699 2020-08-01
# 45277                    0.588 2020-08-01
# 45466                    0.535 2020-08-01
# 45736                      nan 2020-08-01
# 46006                      nan 2020-08-01
#
# [211 rows x 42 columns]

# %%
f, ax = plt.subplots(figsize=(16, 10))
sns.heatmap(covid_agost.corr(), annot=False, fmt="f", linewidths=.5, ax=ax)
f, ax = plt.subplots(figsize=(16, 10))
sns.heatmap(abs(covid_agost.corr()), annot=False, fmt="f", linewidths=.5, ax=ax)
# Out:
# <AxesSubplot:>

# %%
selected_columns = ["positive_rate", "aged_65_older", "hospital_beds_per_thousand", "extreme_poverty", "human_development_index"]
sns.pairplot(covid_agost[selected_columns])

# %% [markdown]
# A continuació, teniu unes funcions que de ben segur haurieu de completar per tal de poder respondre a les preguntes. Podeu implementar-les vosaltres mateixos i llavors comparar-les amb funcions de sklearn (si existeixen)

# %%
def mostra_correlacions(data):
    # TODO mostra les correlacions entre els atributs 
    pass

def normalitzador_de_dades(data):
    # TODO aplica algun tipus de normalitzador als atributs
    return data

def separar_train_test(data, target, ratio=0.8):
    # TODO retorna les dades en dos subconjunts diferents amb un ratio de 'ratio'
    data_train = data
    data_val = []
    target_train = target
    target_val = []
    return data_train, data_val, target_train, target_val 

def aplicar_regressor_lineal(data, target):
    prediccions = []
    # TODO aplica un regressor lineal amb les dades per predir el target
    return prediccions


def calcula_metrica_error(prediccions, target, tipus):
    # TODO utilitza varies metriques segons la var "tipus" que analitzin les prediccions
    if tipus == "mse":
        return 0
    elif tipus == "r2":
        return 0
    else:
        print ("Metrica {} no reconeguda".format(tipus))
        return -1

# %% [markdown]
# ## A. Exploració de la base de dades (30%)
#
# En aquest apartat aprendrem a analitzar les dades de la base de dades. Les següents funcions ens poden anar bé:
#
# * [pandas.read_csv](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html)
# * [DataFrame.groupby](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.corr.html)
# * [DataFrame.corr](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.corr.html)
# * [sns.pairplot](https://seaborn.pydata.org/generated/seaborn.pairplot.html)
#
# Podeu veure algunes idees de
# https://www.kaggle.com/therealcyberlord/coronavirus-covid-19-visualization-prediction
#
# Descripció dels camps:
# https://github.com/owid/covid-19-data/blob/master/public/data/owid-covid-codebook.csv

# %% [markdown]
# ### Preguntes a respondre
# 1. Dimensionalitat de la BBDD. Quants exemples, quantes caracteristiques tenim.
# 2. Com són les caracteristiques?
# 3. Hi tenim totes les dades (quin % de dades tenim)
# 4. Quin tipus de atributs tenim a la base de dades.
# 5. Mostra els atributs més rellevants.
# 6. Quins atributs están més correlacionats. Mostra'ls.
# 7. Mostra (almenys) 5 tipus diferents de gràfiques sobre les dades.
# 8. Els valors es troben tots a la mateixa escala? Ens importa?
# 9. Quins atributs tenen una distribució Guassiana?
# 10. Quin és l'atribut objectiu? Per què?

# %% [markdown]
# ## B. Ús de regressor Lineal (30%)
#
#
# Funcions a tenir en compte
#
# * [data preprocessing](https://scikit-learn.org/stable/modules/preprocessing.html)
#
# * [sklearn.pipeline.make_pipeline](https://scikit-learn.org/stable/modules/generated/sklearn.pipeline.make_pipeline.html)
#
# * [sklearn.linear_model.LinearRegression](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LinearRegression.html)
#
# * [sklearn.linear_model.SGDRegressor](https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.SGDRegressor.html)
#
# * [sklearn.metrics.mean_squared_error](https://scikit-learn.org/stable/modules/generated/sklearn.metrics.mean_squared_error.html)

# %% [markdown]
# ### Preguntes a respondre
# 1. Aprén un Regressor Lineal amb totes les dades
# 2. Calcula l'error quadràtic mitjà del regressor per a cada un dels atributs de la base de dades. Quin atribut té l'error més baix. Mostra'ls.
# 3. És millor o pitjor que utilitzant totes les dades? Per què?
# 4. Tenen alguna relació els atributs amb distribucions Gaussianes i els que tenen un error més petit?
# 5. Què passa si normalitzes les dades? El error és més baix?
# 6. Significa això que el regressor és més precís? Passa el mateix amb altres mètriques?
# 7. Heu après un LinearRegression o un SGDRegressor? Sabeu quines diferencies hi ha? Compareu-los [Pista](https://stackoverflow.com/questions/34469237/linear-regression-and-gradient-descent-in-scikit-learn-pandas)

# %% [markdown]
# ## C. Demostració d'assoliment (A+B en una nova BBDD) (20%)
#
# La puntuació d'aquesta secció dependrà de la originalitat, i el treball realizat l'analisis i procesat d'una base de dades alternativa de lliure elecció. Recordeu que podeu reaprofitar la majoria del codi si ho heu implementat en funcions.

# %% [markdown]
# ## D. Implementació Regressor Lineal (20%)
#
# En aquest exercici, es tracta d'implementar en python el procés de descens del gradient explicat a les classes de teoria, i comparar-lo amb els resultats obtinguts amb l'apartat (B).
#
# $$J(w) = \frac{1}{2m} \left[ \sum^m_{i=1}(f(x^{i}; w) - y^{i})^2 + \lambda\sum_{j=1}^{n}(w_{j}^2) \right]$$
#
# Fixeu-vos que $J$ retorna el `mse`. Per a trobar $w_j$, repetir fins convergència:
# $$w_0 = w_0 - \alpha \frac{1}{m} \sum_{i=1}^{m}(f(x^{i}; w)-y^{i}) \cdot 1$$
# $$w_j = w_j - \alpha \left[\frac{1}{m} \sum_{i=1}^{m}(f(x^{i}; w)-y^{i}) \cdot x_{j}^{i} - \frac{\lambda}{m}w_{j} \right]$$
#
#
# ó:
#
# $$w_{j} := w_{j} \left(1-\alpha \frac{\lambda}{m} \right) - \alpha\frac{\lambda}{m} \sum_{i=1}^{m}(f(x^{i}; w)-y^{i}) \cdot x_{j}^{i}$$
#
# On si considerem un regressor lineal (el model és una recta), llavors $w_0$ i $w_1$ representen, respectivament, la $b$ i $a$ de la fòrmula de la recta:
#
# $$h_\theta(x^{(i)}) = ax + b$$
#
# $\alpha$ és el learning rate, i $h_\theta(x^{(i)})$ és la funció que fa la regressió, és a dir, la funció que prediu el valor de $y^{(i)}$ donat un(s) atribut(s) concret(s) $x^{(i)}$.
#
# Així, tenint calculat el model en l'últim punt del primer exercici, ja sabeu quin resultat hauríeu d'obtenir. O no, perquè la vostra implementació pot ser millor! En concret, es tracta de desenvolupar aquestes tasques:
#
# * Definir la funció de cost i del gradient
#
# * Estudiar com l'ús de regularitzadors afecta el resultat: overfitting, underfitting, etc.
#
# * Visualització de les dades a analitzar i explicació pas a pas del procediment
#
# * Visualització del procés de descens de gradient
#
# * Modificar el learning rate i el nombre d'iteracions
#
# <img src="https://miro.medium.com/max/810/1*UUHvSixG7rX2EfNFTtqBDA.gif">
#
# Per a la implementació us podeu basar en el següent esquelet:

# %%
class Regressor(object):
    def __init__(self, w0, w1, alpha):
        # Inicialitzem w0 i w1 
        self.w0 = w0
        self.w1 = w1
        self.alpha = alpha

        
    def predict(self, x):
        # implementar aqui la funció de prediccio
        pass
    
    def __update(self, x, y):
        # actualitzar aqui els pesos donada la x i la y real.
        # h = fer prediccio(x)
        
        # calcular gradient w0
        # calcular gradient w1
        
        # actualitzar w0 amb alpha
        # actualitzar w1 amd alpha
        
        # retornar el error
        return 0
    
    def fit(self, x, y, max_iter=1000, epsilon=1e-3):
        # Entrenar durant max_iter iteracions o fins que la millora sigui inferior a epsilon
        pass

# %% [markdown]
# Així es podrà contestar a aquestes preguntes:
#
# 1. Com influeixen tots els paràmetres en el procés de descens?
# 2. Quins valors de learning rate convergeixen més ràpid a la solució òptima?
# 3. Com influeix la inicialització del model en el resultat final?
# 4. Quina diferència (quantitativa i qualitativa) hi ha entre el vostre regressor i el de la llibreria ?
# 5. Evalueu mètriques de execució

# %% [markdown]
# ## (Extra) Implementació Regresor polinomial (+10%, max: 10pts)
# 1. Quins parametres heu de cambiar al vostre Regressor per tal de poder predir amb funcions polinomials?
# 2. Quines funcions polinomials (de diferent grau, de diferents combinacions d'atributs, ...) heu escollit per ser apreses amb el vostre descens del gradient? quina ha donat el millor resultat (en error i rapidesa en convergència)?
# 3. Utilitzeu el regularitzador en la fòrmula de funció de cost i descens del gradient i proveu polinomis de diferent grau. Com afecta el valor del regularitzador?
# 4. Té sentit el model (polinomial) trobat quan es visualitza sobre les dades?
